# %%
# %reset -f

import torch
import numpy as np
from pkg_resources import resource_stream
from plpm.constants.BaselineCase import base
import matplotlib.pyplot as plt

pig1388 = np.loadtxt(resource_stream(
    'plpm', '../data/ExperimentalData/pigs/Plv_Vlv_Paorta_Pig1388.csv'),
    delimiter=",")
pig1388 = torch.from_numpy(pig1388)
pig1388[:, 0] = pig1388[:, 0] / pig1388[:, 0].max() * base.Tc

pig1574 = np.loadtxt(resource_stream(
    'plpm', '../data/ExperimentalData/pigs/Plv_Vlv_Paorta_Pig1574.csv'),
    delimiter=",")
pig1574 = torch.from_numpy(pig1574)
pig1574[:, 0] = pig1574[:, 0] / pig1574[:, 0].max() * base.Tc

pig1605 = np.loadtxt(resource_stream(
    'plpm', '../data/ExperimentalData/pigs/Plv_Vlv_Paorta_Pig1605.csv'),
    delimiter=",")
pig1605 = torch.from_numpy(pig1605)
pig1605[:, 0] = pig1605[:, 0] / pig1605[:, 0].max() * base.Tc

pig2455 = np.loadtxt(resource_stream(
    'plpm', '../data/ExperimentalData/pigs/Plv_Vlv_Paorta_Pig2455.csv'),
    delimiter=",")
pig2455 = torch.from_numpy(pig2455)
pig2455[:, 0] = pig2455[:, 0] / pig2455[:, 0].max() * base.Tc

pig2856 = np.loadtxt(resource_stream(
    'plpm', '../data/ExperimentalData/pigs/Plv_Vlv_Paorta_Pig2856.csv'),
    delimiter=",")
pig2856 = torch.from_numpy(pig2856)
pig2856[:, 0] = pig2856[:, 0] / pig2856[:, 0].max() * base.Tc

pig3072 = np.loadtxt(resource_stream(
    'plpm', '../data/ExperimentalData/pigs/Plv_Vlv_Paorta_Pig3072.csv'),
    delimiter=",")
pig3072 = torch.from_numpy(pig3072)
pig3072[:, 0] = pig3072[:, 0] / pig3072[:, 0].max() * base.Tc

pig3138 = np.loadtxt(resource_stream(
    'plpm', '../data/ExperimentalData/pigs/Plv_Vlv_Paorta_Pig3138.csv'),
    delimiter=",")
pig3138 = torch.from_numpy(pig3138)
pig3138[:, 0] = pig3138[:, 0] / pig3138[:, 0].max() * base.Tc

pig3802 = np.loadtxt(resource_stream(
    'plpm', '../data/ExperimentalData/pigs/Plv_Vlv_Paorta_Pig3802.csv'),
    delimiter=",")
pig3802 = torch.from_numpy(pig3802)
pig3802[:, 0] = pig3802[:, 0] / pig3802[:, 0].max() * base.Tc

pig3888 = np.loadtxt(resource_stream(
    'plpm', '../data/ExperimentalData/pigs/Plv_Vlv_Paorta_Pig3888.csv'),
    delimiter=",")
pig3888 = torch.from_numpy(pig3888)
pig3888[:, 0] = pig3888[:, 0] / pig3888[:, 0].max() * base.Tc

pig3946 = np.loadtxt(resource_stream(
    'plpm', '../data/ExperimentalData/pigs/Plv_Vlv_Paorta_Pig3946.csv'),
    delimiter=",")
pig3946 = torch.from_numpy(pig3946)
pig3946[:, 0] = pig3946[:, 0] / pig3946[:, 0].max() * base.Tc

pigs = [pig1388, pig1574, pig1605, pig2455, pig2856, pig3072, pig3138,
        pig3802, pig3888, pig3946]

for pig in pigs:
    pig[:, [1, 2]] = pig[:, [2, 1]]
    pig_name = [name for name in globals() if globals()[name] is pig][0]
    file_path = f'../../data/ExperimentalData/processed/{pig_name}.csv'
    np.savetxt(file_path,
               pig,
               delimiter=',',
               header='t (ms), vlv (ml), plv (mmHg), part (mmHg)',
               comments='')
    print(f'Saved {pig_name} to {file_path}')


fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(12, 6))
for i in range(2):
    for j in range(5):
        ax[i, j].plot(pigs[i + j*2][:, 1], pigs[i + j*2][:, 2])
plt.show()

fig, ax = plt.subplots(nrows=5, ncols=2, figsize=(12, 12))
for i in range(5):
    for j in range(2):
        ax[i, j].plot(pigs[i + j*5][:, 0], pigs[i + j*5][:, 1])
plt.show()
# Out:
# Saved pig1388 to ../../data/ExperimentalData/processed/pig1388.csv
# Saved pig1574 to ../../data/ExperimentalData/processed/pig1574.csv
# Saved pig1605 to ../../data/ExperimentalData/processed/pig1605.csv
# Saved pig2455 to ../../data/ExperimentalData/processed/pig2455.csv
# Saved pig2856 to ../../data/ExperimentalData/processed/pig2856.csv
# Saved pig3072 to ../../data/ExperimentalData/processed/pig3072.csv
# Saved pig3138 to ../../data/ExperimentalData/processed/pig3138.csv
# Saved pig3802 to ../../data/ExperimentalData/processed/pig3802.csv
# Saved pig3888 to ../../data/ExperimentalData/processed/pig3888.csv
# Saved pig3946 to ../../data/ExperimentalData/processed/pig3946.csv

# %%
# %reset -f

import torch
import numpy as np
from pkg_resources import resource_stream
from plpm.constants.BaselineCase import base
import matplotlib.pyplot as plt

PLV_b = np.loadtxt(resource_stream(
    'plpm', '../data/ExperimentalData/pigs2/Pig2910_PLV_Baseline.csv'),
    delimiter=",")
PLV_b = torch.from_numpy(PLV_b)
PLV_b[:, 0] = PLV_b[:, 0] / PLV_b[:, 0].max() * base.Tc

VLV_b = np.loadtxt(resource_stream(
    'plpm', '../data/ExperimentalData/pigs2/Pig2910_VLV_echo_Baseline.csv'),
    delimiter=",")
VLV_b = torch.from_numpy(VLV_b)
VLV_b[:, 0] = VLV_b[:, 0] / VLV_b[:, 0].max() * base.Tc

PLV_b_interpolated = np.interp(VLV_b[:, 0], PLV_b[:, 0], PLV_b[:, 1])
plt.plot(VLV_b[:, 1], PLV_b_interpolated, label='baseline')

PLV_D = np.loadtxt(resource_stream(
    'plpm', '../data/ExperimentalData/pigs2/Pig2910_PLV_Dobutamine.csv'),
    delimiter=",")
PLV_D = torch.from_numpy(PLV_D)
PLV_D[:, 0] = PLV_D[:, 0] / PLV_D[:, 0].max() * base.Tc

VLV_D = np.loadtxt(resource_stream(
    'plpm', '../data/ExperimentalData/pigs2/Pig2910_VLV_echo_Dobutamine.csv'),
    delimiter=",")
VLV_D = torch.from_numpy(VLV_D)
VLV_D[:, 0] = VLV_D[:, 0] / VLV_D[:, 0].max() * base.Tc

PLV_D_interpolated = np.interp(VLV_D[:, 0], PLV_D[:, 0], PLV_D[:, 1])
plt.plot(VLV_D[:, 1], PLV_D_interpolated, label='Dobutamine')


pig2910baseline = torch.from_numpy(np.vstack((VLV_b[:, 0], VLV_b[:, 1], PLV_b_interpolated))).T
pig2910dobutamine = torch.from_numpy(np.vstack((VLV_D[:, 0], VLV_D[:, 1], PLV_D_interpolated))).T

pigs = [pig2910baseline, pig2910dobutamine]

for pig in pigs:
    pig_name = [name for name in globals() if globals()[name] is pig][0]
    file_path = f'../../data/ExperimentalData/processed/{pig_name}.csv'
    np.savetxt(file_path,
               pig,
               delimiter=',',
               header='t (ms), vlv (ml), plv (mmHg), part (mmHg)',
               comments='')
    print(f'Saved {pig_name} to {file_path}')
plt.legend()
plt.show()
# Out:
# Saved pig2910baseline to ../../data/ExperimentalData/processed/pig2910baseline.csv
# Saved pig2910dobutamine to ../../data/ExperimentalData/processed/pig2910dobutamine.csv

# %%
# %reset -f

import torch
import numpy as np
from pkg_resources import resource_stream
from plpm.constants.BaselineCase import base
import matplotlib.pyplot as plt

PLV_b = np.loadtxt(resource_stream(
    'plpm', '../data/ExperimentalData/pigs3/Pig2873_PLV_Baseline.csv'),
    delimiter=",")
PLV_b = torch.from_numpy(PLV_b)
PLV_b[:, 0] = PLV_b[:, 0] / PLV_b[:, 0].max() * base.Tc

VLV_b = np.loadtxt(resource_stream(
    'plpm', '../data/ExperimentalData/pigs3/Pig2873_VLV_echo_Baseline.csv'),
    delimiter=",")
VLV_b = torch.from_numpy(VLV_b)
VLV_b[:, 0] = VLV_b[:, 0] / VLV_b[:, 0].max() * base.Tc

PLV_b_interpolated = np.interp(VLV_b[:, 0], PLV_b[:, 0], PLV_b[:, 1])
plt.plot(VLV_b[:, 1], PLV_b_interpolated, label='baseline')

Pao_b = np.loadtxt(resource_stream(
    'plpm', '../data/ExperimentalData/pigs3/Pig2873_Paorta_Baseline.csv'),
    delimiter=",")
Pao_b = torch.from_numpy(Pao_b)
Pao_b[:, 0] = Pao_b[:, 0] / Pao_b[:, 0].max() * base.Tc

Pao_b_interpolated = np.interp(VLV_b[:, 0], Pao_b[:, 0], Pao_b[:, 1])

pig2873baseline = torch.from_numpy(np.vstack((VLV_b[:, 0], VLV_b[:, 1], PLV_b_interpolated, Pao_b_interpolated))).T


PLV_D = np.loadtxt(resource_stream(
    'plpm', '../data/ExperimentalData/pigs3/Pig2873_PLV_Dobutamine.csv'),
    delimiter=",")
PLV_D = torch.from_numpy(PLV_D)
PLV_D[:, 0] = PLV_D[:, 0] / PLV_D[:, 0].max() * base.Tc

VLV_D = np.loadtxt(resource_stream(
    'plpm', '../data/ExperimentalData/pigs3/Pig2873_VLV_echo_Dobutamine.csv'),
    delimiter=",")
VLV_D = torch.from_numpy(VLV_D)
VLV_D[:, 0] = VLV_D[:, 0] / VLV_D[:, 0].max() * base.Tc

PLV_D_interpolated = np.interp(VLV_D[:, 0], PLV_D[:, 0], PLV_D[:, 1])
plt.plot(VLV_D[:, 1], PLV_D_interpolated, label='Dobutamine')

pig2873dobutamine = torch.from_numpy(np.vstack((VLV_D[:, 0], VLV_D[:, 1], PLV_D_interpolated))).T

pigs = [pig2873baseline, pig2873dobutamine]

for pig in pigs:
    pig_name = [name for name in globals() if globals()[name] is pig][0]
    file_path = f'../../data/ExperimentalData/processed/{pig_name}.csv'

    np.savetxt(file_path,
               pig,
               delimiter=',',
               header='t (ms), vlv (ml), plv (mmHg), part (mmHg)',
               comments='')
                
    print(f'Saved {pig_name} to {file_path}')

plt.legend()
plt.show()
# Out:
# Saved pig2873baseline to ../../data/ExperimentalData/processed/pig2873baseline.csv
# Saved pig2873dobutamine to ../../data/ExperimentalData/processed/pig2873dobutamine.csv

# %%
# %reset -f

import torch
import numpy as np
from pkg_resources import resource_stream
from plpm.constants.BaselineCase import base
import matplotlib.pyplot as plt

PLV_b = np.loadtxt(resource_stream(
    'plpm', '../data/ExperimentalData/pigs4/Pig872_PLV_Baseline.csv'),
    delimiter=",")
PLV_b = torch.from_numpy(PLV_b)
PLV_b[:, 0] = PLV_b[:, 0] / PLV_b[:, 0].max() * base.Tc

VLV_b = np.loadtxt(resource_stream(
    'plpm', '../data/ExperimentalData/pigs4/Pig872_VLV_echo_Baseline.csv'),
    delimiter=",")
VLV_b = torch.from_numpy(VLV_b)
VLV_b[:, 0] = VLV_b[:, 0] / VLV_b[:, 0].max() * base.Tc

PLV_b_interpolated = np.interp(VLV_b[:, 0], PLV_b[:, 0], PLV_b[:, 1])
plt.plot(VLV_b[:, 1], PLV_b_interpolated, label='baseline')

Pao_b = np.loadtxt(resource_stream(
    'plpm', '../data/ExperimentalData/pigs4/Pig872_Paorta_Baseline.csv'),
    delimiter=",")
Pao_b = torch.from_numpy(Pao_b)
Pao_b[:, 0] = Pao_b[:, 0] / Pao_b[:, 0].max() * base.Tc

Pao_b_interpolated = np.interp(VLV_b[:, 0], Pao_b[:, 0], Pao_b[:, 1])

pig872baseline = torch.from_numpy(np.vstack((VLV_b[:, 0], VLV_b[:, 1], PLV_b_interpolated, Pao_b_interpolated))).T


PLV_D = np.loadtxt(resource_stream(
    'plpm', '../data/ExperimentalData/pigs4/Pig872_PLV_Dobutamine.csv'),
    delimiter=",")
PLV_D = torch.from_numpy(PLV_D)
PLV_D[:, 0] = PLV_D[:, 0] / PLV_D[:, 0].max() * base.Tc

VLV_D = np.loadtxt(resource_stream(
    'plpm', '../data/ExperimentalData/pigs4/Pig872_VLV_echo_Dobutamine.csv'),
    delimiter=",")
VLV_D = torch.from_numpy(VLV_D)
VLV_D[:, 0] = VLV_D[:, 0] / VLV_D[:, 0].max() * base.Tc

PLV_D_interpolated = np.interp(VLV_D[:, 0], PLV_D[:, 0], PLV_D[:, 1])
plt.plot(VLV_D[:, 1], PLV_D_interpolated, label='Dobutamine')

Pao_D = np.loadtxt(resource_stream(
    'plpm', '../data/ExperimentalData/pigs4/Pig872_Paorta_Dobutamine.csv'),
    delimiter=",")
Pao_D = torch.from_numpy(Pao_D)
Pao_D[:, 0] = Pao_D[:, 0] / Pao_D[:, 0].max() * base.Tc

Pao_D_interpolated = np.interp(VLV_D[:, 0], Pao_D[:, 0], Pao_D[:, 1])

pig872dobutamine = torch.from_numpy(np.vstack((VLV_D[:, 0], VLV_D[:, 1], PLV_D_interpolated, Pao_D_interpolated))).T

pigs = [pig872baseline, pig872dobutamine]

for pig in pigs:
    pig_name = [name for name in globals() if globals()[name] is pig][0]
    file_path = f'../../data/ExperimentalData/processed/{pig_name}.csv'

    np.savetxt(file_path,
               pig,
               delimiter=',',
               header='t (ms), vlv (ml), plv (mmHg), part (mmHg)',
               comments='')
                
    print(f'Saved {pig_name} to {file_path}')

plt.legend()
plt.show()
# Out:
# Saved pig872baseline to ../../data/ExperimentalData/processed/pig872baseline.csv
# Saved pig872dobutamine to ../../data/ExperimentalData/processed/pig872dobutamine.csv
